# %%
# ==========================================
# CHESS OUTCOME PREDICTION — PREPROCESSING
# ==========================================

# --- Imports (everything used in this notebook lives here) ---
from pathlib import Path
import os
import json
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 200)

# --- Paths ---
NB_DIR = Path.cwd()
CANDIDATES = [
    NB_DIR / "../data/raw_chess_games.csv",
    NB_DIR / "../../data/raw_chess_games.csv",
    NB_DIR / "data/raw_chess_games.csv",
]

RAW_CSV = next((p.resolve() for p in CANDIDATES if p.exists()), None)
if RAW_CSV is None:
    raise FileNotFoundError(
        "Could not find raw_chess_games.csv. Expected it under ../data/ relative to this notebook."
    )

RESULTS_DIR = (NB_DIR / "../results").resolve()
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

# --- Load ---
df = pd.read_csv(RAW_CSV)
print(f"Loaded: {RAW_CSV}")
print("Initial shape:", df.shape)
df.head()
# Out:
# Loaded: E:\Github Projects\chess-outcome-prediction\data\raw_chess_games.csv
# Initial shape: (214980, 23)
#                                 game_id white_username black_username  \
# 0  f57a1313-0f25-11f0-8731-6cfe544c0428     nihalsarin         Hikaru
# 1  d2b8e5d3-0f23-11f0-8731-6cfe544c0428         Hikaru     nihalsarin
# 2  70b20004-0f27-11f0-8731-6cfe544c0428     nihalsarin         Hikaru
# 3  35b89065-0f25-11f0-8731-6cfe544c0428         Hikaru     nihalsarin
# 4  23a8b502-0f29-11f0-8731-6cfe544c0428     nihalsarin         Hikaru
#
#    white_rating  black_rating white_country black_country   result  \
# 0          3222          3307    nihalsarin        hikaru      1-0
# 1          3330          3199        hikaru    nihalsarin      1-0
# 2          3226          3303    nihalsarin        hikaru      1-0
# 3          3317          3212        hikaru    nihalsarin  1/2-1/2
# 4          3214          3315    nihalsarin        hikaru  1/2-1/2
#
#    termination time_control time_class  initial_time  increment        date  \
# 0    checkmate          180      blitz           3.0        0.0  2025-04-01
# 1    checkmate          180      blitz           3.0        0.0  2025-04-01
# 2    checkmate          180      blitz           3.0        0.0  2025-04-01
# 3   repetition          180      blitz           3.0        0.0  2025-04-01
# 4  resignation          180      blitz           3.0        0.0  2025-04-01
#
#                                                  eco  opening  num_moves  \
# 0  https://www.chess.com/openings/Modern-Defense-...      NaN      312.0
# 1  https://www.chess.com/openings/Nimzowitsch-Lar...      NaN      320.0
# 2  https://www.chess.com/openings/Torre-Attack-Fi...      NaN      334.0
# 3  https://www.chess.com/openings/Bishops-Opening...      NaN      274.0
# 4  https://www.chess.com/openings/Torre-Attack......      NaN      496.0
#
#   rated event     source  avg_rating  rating_diff time_category
# 0  True   NaN  chess.com      3264.5        -85.0         blitz
# 1  True   NaN  chess.com      3264.5        131.0         blitz
# 2  True   NaN  chess.com      3264.5        -77.0         blitz
# 3  True   NaN  chess.com      3264.5        105.0         blitz
# 4  True   NaN  chess.com      3264.5       -101.0         blitz

# %%
# ==========================================
# 2. Inspect Dataset Info
# ==========================================

# If this cell is run before Cell 1, reload the dataset for safety
if "df" not in globals():
    df = pd.read_csv(RAW_CSV)
    print(f"(Re)loaded: {RAW_CSV}")

print("Shape:", df.shape)
df.info()
display(df.head(10))
display(df.describe(include="all").transpose().head(50))
# Out:
# Shape: (214980, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214980 entries, 0 to 214979
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   game_id         214980 non-null  object
#  1   white_username  214980 non-null  object
#  2   black_username  214980 non-null  object
#  3   white_rating    214980 non-null  int64
#  4   black_rating    214980 non-null  int64
#  5   white_country   200047 non-null  object
#  6   black_country   200047 non-null  object
#  7   result          214980 non-null  object
#  8   termination     200047 non-null  object
#  9   time_control    200047 non-null  object
#  10  time_class      200047 non-null  object
#  11  initial_time    200047 non-null  float64
#  12  increment       200047 non-null  float64
#  13  date            200047 non-null  object
#  14  eco             197327 non-null  object
#  15  opening         0 non-null       float64
#  16  num_moves       200047 non-null  float64
#  17  rated           200047 non-null  object
#  18  event           33952 non-null   object
#  19  source          214980 non-null  object
#  20  avg_rating      214980 non-null  float64
#  21  rating_diff     200047 non-null  float64
#  22  time_category   200047 non-null  object
# dtypes: float64(6), int64(2), object(15)
# memory usage: 37.7+ MB
#                                 game_id white_username black_username  \
# 0  f57a1313-0f25-11f0-8731-6cfe544c0428     nihalsarin         Hikaru
# 1  d2b8e5d3-0f23-11f0-8731-6cfe544c0428         Hikaru     nihalsarin
# 2  70b20004-0f27-11f0-8731-6cfe544c0428     nihalsarin         Hikaru
# 3  35b89065-0f25-11f0-8731-6cfe544c0428         Hikaru     nihalsarin
# 4  23a8b502-0f29-11f0-8731-6cfe544c0428     nihalsarin         Hikaru
# 5  d1939b12-0f2a-11f0-8731-6cfe544c0428     nihalsarin         Hikaru
# 6  bb63d0f6-0f26-11f0-8731-6cfe544c0428         Hikaru     nihalsarin
# 7  050015c6-0f2a-11f0-8731-6cfe544c0428         Hikaru     nihalsarin
# 8  38496dee-0f28-11f0-8731-6cfe544c0428         Hikaru     nihalsarin
# 9  97019d9d-0f24-11f0-8731-6cfe544c0428     nihalsarin         Hikaru
#
#    white_rating  black_rating white_country black_country   result  \
# 0          3222          3307    nihalsarin        hikaru      1-0
# 1          3330          3199        hikaru    nihalsarin      1-0
# 2          3226          3303    nihalsarin        hikaru      1-0
# 3          3317          3212        hikaru    nihalsarin  1/2-1/2
# 4          3214          3315    nihalsarin        hikaru  1/2-1/2
# 5          3211          3318    nihalsarin        hikaru  1/2-1/2
# 6          3313          3216        hikaru    nihalsarin      1-0
# 7          3321          3208        hikaru    nihalsarin      1-0
# 8          3309          3220        hikaru    nihalsarin      1-0
# 9          3210          3319    nihalsarin        hikaru      1-0
#
#    termination time_control time_class  initial_time  increment        date  \
# 0    checkmate          180      blitz           3.0        0.0  2025-04-01
# 1    checkmate          180      blitz           3.0        0.0  2025-04-01
# 2    checkmate          180      blitz           3.0        0.0  2025-04-01
# 3   repetition          180      blitz           3.0        0.0  2025-04-01
# 4  resignation          180      blitz           3.0        0.0  2025-04-01
# 5      unknown          180      blitz           3.0        0.0  2025-04-01
# 6    checkmate          180      blitz           3.0        0.0  2025-04-01
# 7    checkmate          180      blitz           3.0        0.0  2025-04-01
# 8    checkmate          180      blitz           3.0        0.0  2025-04-01
# 9    checkmate          180      blitz           3.0        0.0  2025-04-01
#
#                                                  eco  opening  num_moves  \
# 0  https://www.chess.com/openings/Modern-Defense-...      NaN      312.0
# 1  https://www.chess.com/openings/Nimzowitsch-Lar...      NaN      320.0
# 2  https://www.chess.com/openings/Torre-Attack-Fi...      NaN      334.0
# 3  https://www.chess.com/openings/Bishops-Opening...      NaN      274.0
# 4  https://www.chess.com/openings/Torre-Attack......      NaN      496.0
# 5  https://www.chess.com/openings/Caro-Kann-Defen...      NaN      572.0
# 6  https://www.chess.com/openings/Nimzowitsch-Lar...      NaN      358.0
# 7  https://www.chess.com/openings/Trompowsky-Atta...      NaN      486.0
# 8  https://www.chess.com/openings/Reti-Opening-Ni...      NaN      776.0
# 9  https://www.chess.com/openings/Indian-Game-Sla...      NaN      264.0
#
#   rated event     source  avg_rating  rating_diff time_category
# 0  True   NaN  chess.com      3264.5        -85.0         blitz
# 1  True   NaN  chess.com      3264.5        131.0         blitz
# 2  True   NaN  chess.com      3264.5        -77.0         blitz
# 3  True   NaN  chess.com      3264.5        105.0         blitz
# 4  True   NaN  chess.com      3264.5       -101.0         blitz
# 5  True   NaN  chess.com      3264.5       -107.0         blitz
# 6  True   NaN  chess.com      3264.5         97.0         blitz
# 7  True   NaN  chess.com      3264.5        113.0         blitz
# 8  True   NaN  chess.com      3264.5         89.0         blitz
# 9  True   NaN  chess.com      3264.5       -109.0         blitz
#                    count  unique  \
# game_id           214980  214980
# white_username    214980   41650
# black_username    214980   41611
# white_rating    214980.0     NaN
# black_rating    214980.0     NaN
# white_country     200047   40686
# black_country     200047   40612
# result            214980      15
# termination       200047       8
# time_control      200047      89
# time_class        200047       4
# initial_time    200047.0     NaN
# increment       200047.0     NaN
# date              200047    2901
# eco               197327   31001
# opening              0.0     NaN
# num_moves       200047.0     NaN
# rated             200047       1
# event              33952    1785
# source            214980       1
# avg_rating      214980.0     NaN
# rating_diff     200047.0     NaN
# time_category     200047       4
#
#                                                               top    freq  \
# game_id                      f57a1313-0f25-11f0-8731-6cfe544c0428       1
# white_username                                           francyIM     263
# black_username                                           francyIM     269
# white_rating                                                  NaN     NaN
# black_rating                                                  NaN     NaN
# white_country                                            dpopadic     248
# black_country                                            francyim     252
# result                                                        1-0   96830
# termination                                             checkmate  112899
# time_control                                                  180   86198
# time_class                                                  blitz  138352
# initial_time                                                  NaN     NaN
# increment                                                     NaN     NaN
# date                                                   2025-04-01    2703
# eco                      https://www.chess.com/openings/Undefined    3185
# opening                                                       NaN     NaN
# num_moves                                                     NaN     NaN
# rated                                                        True  200047
# event           https://api.chess.com/pub/tournament/early-tit...     589
# source                                                  chess.com  214980
# avg_rating                                                    NaN     NaN
# rating_diff                                                   NaN     NaN
# time_category                                               blitz  138352
#
#                        mean         std     min     25%     50%     75%  \
# game_id                 NaN         NaN     NaN     NaN     NaN     NaN
# white_username          NaN         NaN     NaN     NaN     NaN     NaN
# black_username          NaN         NaN     NaN     NaN     NaN     NaN
# white_rating     2409.71556  335.325708   348.0  2209.0  2445.0  2637.0
# black_rating    2408.870955  335.117792   112.0  2209.0  2444.0  2636.0
# white_country           NaN         NaN     NaN     NaN     NaN     NaN
# black_country           NaN         NaN     NaN     NaN     NaN     NaN
# result                  NaN         NaN     NaN     NaN     NaN     NaN
# termination             NaN         NaN     NaN     NaN     NaN     NaN
# time_control            NaN         NaN     NaN     NaN     NaN     NaN
# time_class              NaN         NaN     NaN     NaN     NaN     NaN
# initial_time       2.830409    2.456262     0.0     1.0     3.0     3.0
# increment          0.426595    1.057597     0.0     0.0     0.0     0.0
# date                    NaN         NaN     NaN     NaN     NaN     NaN
# eco                     NaN         NaN     NaN     NaN     NaN     NaN
# opening                 NaN         NaN     NaN     NaN     NaN     NaN
# num_moves        315.124456  134.437823     0.0   224.0   300.0   398.0
# rated                   NaN         NaN     NaN     NaN     NaN     NaN
# event                   NaN         NaN     NaN     NaN     NaN     NaN
# source                  NaN         NaN     NaN     NaN     NaN     NaN
# avg_rating      2409.293258  324.504479   542.0  2213.0  2442.5  2635.0
# rating_diff        0.772798  166.409518 -1660.0   -60.0     1.0    62.0
# time_category           NaN         NaN     NaN     NaN     NaN     NaN
#
#                    max
# game_id            NaN
# white_username     NaN
# black_username     NaN
# white_rating    3517.0
# black_rating    3400.0
# white_country      NaN
# black_country      NaN
# result             NaN
# termination        NaN
# time_control       NaN
# time_class         NaN
# initial_time     120.0
# increment         60.0
# date               NaN
# eco                NaN
# opening            NaN
# num_moves       4116.0
# rated              NaN
# event              NaN
# source             NaN
# avg_rating      3332.5
# rating_diff     1935.0
# time_category      NaN

# %%
# ==========================================
# 3. Define Target + Drop IDs/Leakage Columns
# ==========================================

# Map results to target labels (adjust to match your CSV’s result column)
if "result" in df.columns:
    result_map = {"1-0": "white", "0-1": "black", "1/2-1/2": "draw"}
    df["target"] = df["result"].map(result_map)

drop_cols = [
    "game_id", "white_username", "black_username",
    "white_country", "black_country",
    "num_moves", "termination", "opening", "eco"
]

df = df.drop(columns=[c for c in drop_cols if c in df.columns], errors="ignore")

print("After dropping ID/leakage cols:", df.shape)
df.head(3)
# Out:
# After dropping ID/leakage cols: (214980, 15)
#    white_rating  black_rating result time_control time_class  initial_time  \
# 0          3222          3307    1-0          180      blitz           3.0
# 1          3330          3199    1-0          180      blitz           3.0
# 2          3226          3303    1-0          180      blitz           3.0
#
#    increment        date rated event     source  avg_rating  rating_diff  \
# 0        0.0  2025-04-01  True   NaN  chess.com      3264.5        -85.0
# 1        0.0  2025-04-01  True   NaN  chess.com      3264.5        131.0
# 2        0.0  2025-04-01  True   NaN  chess.com      3264.5        -77.0
#
#   time_category target
# 0         blitz  white
# 1         blitz  white
# 2         blitz  white

# %%
# ==========================================
# 4. Add Calendar Features + Ratings
# ==========================================

# Convert date → calendar fields
if "date" in df.columns:
    df["date"] = pd.to_datetime(df["date"], errors="coerce")
    df["year"] = df["date"].dt.year
    df["month"] = df["date"].dt.month
    df["dayofweek"] = df["date"].dt.dayofweek
    df = df.drop(columns=["date"])

# Rating-based features
if {"white_rating", "black_rating"} <= set(df.columns):
    df["rating_diff"] = df["white_rating"] - df["black_rating"]
    df["avg_rating"] = (df["white_rating"] + df["black_rating"]) / 2

# Convert booleans to integers
if "rated" in df.columns and df["rated"].dtype == bool:
    df["rated"] = df["rated"].astype(int)

print("Columns now:", list(df.columns))
df.head(3)
# Out:
# Columns now: ['white_rating', 'black_rating', 'result', 'time_control', 'time_class', 'initial_time', 'increment', 'rated', 'event', 'source', 'avg_rating', 'rating_diff', 'time_category', 'target', 'year', 'month', 'dayofweek']
#    white_rating  black_rating result time_control time_class  initial_time  \
# 0          3222          3307    1-0          180      blitz           3.0
# 1          3330          3199    1-0          180      blitz           3.0
# 2          3226          3303    1-0          180      blitz           3.0
#
#    increment rated event     source  avg_rating  rating_diff time_category  \
# 0        0.0  True   NaN  chess.com      3264.5          -85         blitz
# 1        0.0  True   NaN  chess.com      3264.5          131         blitz
# 2        0.0  True   NaN  chess.com      3264.5          -77         blitz
#
#   target    year  month  dayofweek
# 0  white  2025.0    4.0        1.0
# 1  white  2025.0    4.0        1.0
# 2  white  2025.0    4.0        1.0

# %%
# ==========================================
# 5. Handle Missing Values + Encode Categoricals
# ==========================================

target_col = "target"
feature_cols = [c for c in df.columns if c not in {target_col, "result"}]

cat_cols = [c for c in feature_cols if df[c].dtype == "object"]
num_cols = [c for c in feature_cols if c not in cat_cols]

# Impute numerics
for c in num_cols:
    if df[c].isna().any():
        df[c] = df[c].fillna(df[c].median())

# Impute categoricals with "Unknown"
for c in cat_cols:
    df[c] = df[c].fillna("Unknown")

# One-hot encode categoricals
df_encoded = pd.get_dummies(df, columns=cat_cols, drop_first=True)

print("Encoded shape:", df_encoded.shape)
print("Target distribution:")
display(df_encoded[target_col].value_counts(dropna=False))
df_encoded.head(3)
# Out:
# Encoded shape: (214980, 1894)
# Target distribution:
# target
# white    96830
# draw     60817
# black    42400
# NaN      14933
# Name: count, dtype: int64
#    white_rating  black_rating result  initial_time  increment  avg_rating  \
# 0          3222          3307    1-0           3.0        0.0      3264.5
# 1          3330          3199    1-0           3.0        0.0      3264.5
# 2          3226          3303    1-0           3.0        0.0      3264.5
#
#    rating_diff target    year  month  dayofweek  time_control_1/172800  \
# 0          -85  white  2025.0    4.0        1.0                  False
# 1          131  white  2025.0    4.0        1.0                  False
# 2          -77  white  2025.0    4.0        1.0                  False
#
#    time_control_1/259200  time_control_1/432000  time_control_1/604800  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
#
#    time_control_1/86400  time_control_1/864000  time_control_10  \
# 0                 False                  False            False
# 1                 False                  False            False
# 2                 False                  False            False
#
#    time_control_10+0.1  time_control_10+1  time_control_1080+2  \
# 0                False              False                False
# 1                False              False                False
# 2                False              False                False
#
#    time_control_120  time_control_120+1  time_control_120+2  \
# 0             False               False               False
# 1             False               False               False
# 2             False               False               False
#
#    time_control_120+3  time_control_1200  time_control_1200+10  \
# 0               False              False                 False
# 1               False              False                 False
# 2               False              False                 False
#
#    time_control_1200+15  time_control_1200+2  time_control_1200+20  \
# 0                 False                False                 False
# 1                 False                False                 False
# 2                 False                False                 False
#
#    time_control_1200+5  time_control_121  time_control_1220+10  \
# 0                False             False                 False
# 1                False             False                 False
# 2                False             False                 False
#
#    time_control_1220+5  time_control_15  time_control_15+5  \
# 0                False            False              False
# 1                False            False              False
# 2                False            False              False
#
#    time_control_1500+10  time_control_1500+5  time_control_1510  \
# 0                 False                False              False
# 1                 False                False              False
# 2                 False                False              False
#
#    time_control_1560+10  time_control_180  time_control_180+1  \
# 0                 False              True               False
# 1                 False              True               False
# 2                 False              True               False
#
#    time_control_180+2  time_control_180+3  time_control_1800  \
# 0               False               False              False
# 1               False               False              False
# 2               False               False              False
#
#    time_control_182  time_control_185  time_control_20  time_control_20+1  \
# 0             False             False            False              False
# 1             False             False            False              False
# 2             False             False            False              False
#
#    time_control_240  time_control_240+1  time_control_240+2  \
# 0             False               False               False
# 1             False               False               False
# 2             False               False               False
#
#    time_control_2400  time_control_2400+5  time_control_2700  \
# 0              False                False              False
# 1              False                False              False
# 2              False                False              False
#
#    time_control_2700+15  time_control_2700+45  time_control_30  \
# 0                 False                 False            False
# 1                 False                 False            False
# 2                 False                 False            False
#
#    time_control_300  time_control_300+1  time_control_300+2  \
# 0             False               False               False
# 1             False               False               False
# 2             False               False               False
#
#    time_control_300+3  time_control_300+5  time_control_303  \
# 0               False               False             False
# 1               False               False             False
# 2               False               False             False
#
#    time_control_3600  time_control_3600+10  time_control_3600+15  \
# 0              False                 False                 False
# 1              False                 False                 False
# 2              False                 False                 False
#
#    time_control_3600+5  time_control_40  time_control_420+2  \
# 0                False            False               False
# 1                False            False               False
# 2                False            False               False
#
#    time_control_420+3  time_control_420+5  time_control_421+2  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
#
#    time_control_4500+5  time_control_480+5  time_control_5400  \
# 0                False               False              False
# 1                False               False              False
# 2                False               False              False
#
#    time_control_5400+30  time_control_546+4  time_control_6  time_control_60  \
# 0                 False               False           False            False
# 1                 False               False           False            False
# 2                 False               False           False            False
#
#    time_control_60+1  time_control_60+2  time_control_60+3  time_control_60+6  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
#
#    time_control_600  time_control_600+10  time_control_600+2  \
# 0             False                False               False
# 1             False                False               False
# 2             False                False               False
#
#    time_control_600+3  time_control_600+5  time_control_602  time_control_61  \
# 0               False               False             False            False
# 1               False               False             False            False
# 2               False               False             False            False
#
#    time_control_62  time_control_7200  time_control_7200+60  time_control_900  \
# 0            False              False                 False             False
# 1            False              False                 False             False
# 2            False              False                 False             False
#
#    time_control_900+10  time_control_900+2  time_control_900+3  \
# 0                False               False               False
# 1                False               False               False
# 2                False               False               False
#
#    time_control_900+5  time_control_Unknown  ...  \
# 0               False                 False  ...
# 1               False                 False  ...
# 2               False                 False  ...
#
#    event_https://api.chess.com/pub/tournament/the-4th-flaming-tiger-online-blitz-event-1180933  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/the-accused-5283897  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/the-after-party-4443909  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/the-battle-of-helms-deep-1  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/the-best-1-2021  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/the-biggest-world-chess-championship-2025  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/the-new-tournament-welcome  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/the-qualifying-stage-1825362  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/the-queens-gambit-5-1  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/the-warsaw-rising-tournament-2024-1851-2150  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/this-sunday-we-have-a-tournament-with-prizes-439035  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/this-will-go-into-2022-and-beyond  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titeld-tuesday--4140845  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-august-03-2021-2500049  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-august-17-2021-2528831  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-august-31-2021-2546688  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-december-07-2021-2779114  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-december-14-2021-2793478  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-december-21-2021-2825101  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-december-28-2021-2825102  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-february-01-2022-a-2930234  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-february-01-2022-b-2930235  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-january-04-2022-2854823  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-january-11-2022-2868439  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-january-18-2022-2892377  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-january-25-2022-2906225  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-july-06-2021-2443189  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-july-13-2021-2457070  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-july-20-2021-2471236  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-june-01-2021-2359358  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-june-08-2021-2384337  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-june-15-2021-2399019  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-june-22-2021-2413621  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-june-29-2021-2428655  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-may-11-2021-2314015  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-may-18-2021-2319376  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-may-25-2021-2333682  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-may-4-2021-2288851  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-november-02-2021-2688099  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-november-09-2021-2710127  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-november-16-2021-2736618  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-november-23-2021-2750236  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-november-30-2021-2764222  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-october-05-2021-2640054  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-october-12-2021-2654644  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-october-19-2021-2669205  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-october-26-2021-2673117  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-september-02-2025-5905663  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-september-07-2021-2562438  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-september-09-2025-5905665  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-september-16-2025-5925403  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneios-200k-gm-evandro-4409363  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-1-ajedrez-503-1246781  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-abierto-47-aniversario-universidad-nacional-de-entre-ros-1222837  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-blitz-v-san-salvador--3247207  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-chesschocomath-blitz-5909687  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-con-los-maestros-1538828  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-con-premios-3070984  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-de-ajedrez-en-lnea-jden-2024-etapa-regional---regin-central-masculino--4816110  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-de-invierno-9  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-fenamac-1596399  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-matecitos--3562545  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-online-pergamino-3807923  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-por-diversion-214186  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-prueba-5  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-solidario-jorge-fernndez--3979237  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-solidario-jorge-fernndez-4053995  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-torre-blanca-domingo-22-3-18-hs-1163961  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torre-blanca-blitz-del-lunes-23-de-marzo-18-hs-1164834  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/torre-blanca-de-madrugada-1163742  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/tournament-00000000385bc3ca0000000000125ca4  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/tournament-for-honest-players  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/tournoi-1b  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/tsct-2022-amateur-blitz-1659334  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/ttb-open-2020-1  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/turnaj-pratelstvi  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/uefa-nations-league-2022-23-germany-1  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/uji-coba-xclusive-challenge-2320265  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/upasya-039-s-tournament  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/us-chess-regular-open-5176709  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/v-torneo-krakens-1311346  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/vidovdanski-kup-2023-vidovdan-cup-2023  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/women-in-chess-foundation---charity-stream-3920711  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/womens-scc-qualifier-11-1273144  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/womens-scc-qualifier-31-1273143  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/womens-speed-chess-qualifier-1272484  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/world-chess-league-summer-practice-arena-august-31st-4399903  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-play-in-1-4977157  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-play-in-2-4977159  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-play-in-3-4977161  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-play-in-4-4977163  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-qualifier-2-3165382  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-qualifier-4361393  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-qualifier-7-2356652  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/xclusive-challenge-seri-2-u12-2381310  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    event_https://api.chess.com/pub/tournament/zinzino-internetowe-mistrzostwa-polski-1173898  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    time_category_blitz  time_category_bullet  time_category_daily  \
# 0                 True                 False                False
# 1                 True                 False                False
# 2                 True                 False                False
#
#    time_category_rapid
# 0                False
# 1                False
# 2                False
#
# [3 rows x 1894 columns]

# %%
# ==========================================
# 6. Leakage Sanity Check
# ==========================================

banlist = {"num_moves", "termination", "opening", "eco"}
present_banned = [c for c in df_encoded.columns if c in banlist]
if present_banned:
    df_encoded = df_encoded.drop(columns=present_banned, errors="ignore")
    print("Removed banned columns:", present_banned)

print("Final feature count (incl. target):", df_encoded.shape[1])
# Out:
# Final feature count (incl. target): 1894

# %%
# ==========================================
# 7. Save Clean Dataset + Metadata (to data/)
# ==========================================

DATA_DIR = (NB_DIR / "../data").resolve()
DATA_DIR.mkdir(parents=True, exist_ok=True)

clean_csv = DATA_DIR / "clean_chess_games.csv"
df_encoded.to_csv(clean_csv, index=False)

meta = {
    "target_col": target_col,
    "n_rows": int(df_encoded.shape[0]),
    "n_cols": int(df_encoded.shape[1]),
}
with open(DATA_DIR / "clean_metadata.json", "w", encoding="utf-8") as f:
    json.dump(meta, f, indent=2)

print(f"✅ Saved cleaned dataset to: {clean_csv}")
print(f"📝 Saved metadata to: {DATA_DIR / 'clean_metadata.json'}")
df_encoded.head()
# Out:
# ✅ Saved cleaned dataset to: E:\Github Projects\chess-outcome-prediction\results\clean_chess_games.csv
# 📝 Saved metadata to: E:\Github Projects\chess-outcome-prediction\results\clean_metadata.json
#    white_rating  black_rating   result  initial_time  increment  avg_rating  \
# 0          3222          3307      1-0           3.0        0.0      3264.5
# 1          3330          3199      1-0           3.0        0.0      3264.5
# 2          3226          3303      1-0           3.0        0.0      3264.5
# 3          3317          3212  1/2-1/2           3.0        0.0      3264.5
# 4          3214          3315  1/2-1/2           3.0        0.0      3264.5
#
#    rating_diff target    year  month  dayofweek  time_control_1/172800  \
# 0          -85  white  2025.0    4.0        1.0                  False
# 1          131  white  2025.0    4.0        1.0                  False
# 2          -77  white  2025.0    4.0        1.0                  False
# 3          105   draw  2025.0    4.0        1.0                  False
# 4         -101   draw  2025.0    4.0        1.0                  False
#
#    time_control_1/259200  time_control_1/432000  time_control_1/604800  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    time_control_1/86400  time_control_1/864000  time_control_10  \
# 0                 False                  False            False
# 1                 False                  False            False
# 2                 False                  False            False
# 3                 False                  False            False
# 4                 False                  False            False
#
#    time_control_10+0.1  time_control_10+1  time_control_1080+2  \
# 0                False              False                False
# 1                False              False                False
# 2                False              False                False
# 3                False              False                False
# 4                False              False                False
#
#    time_control_120  time_control_120+1  time_control_120+2  \
# 0             False               False               False
# 1             False               False               False
# 2             False               False               False
# 3             False               False               False
# 4             False               False               False
#
#    time_control_120+3  time_control_1200  time_control_1200+10  \
# 0               False              False                 False
# 1               False              False                 False
# 2               False              False                 False
# 3               False              False                 False
# 4               False              False                 False
#
#    time_control_1200+15  time_control_1200+2  time_control_1200+20  \
# 0                 False                False                 False
# 1                 False                False                 False
# 2                 False                False                 False
# 3                 False                False                 False
# 4                 False                False                 False
#
#    time_control_1200+5  time_control_121  time_control_1220+10  \
# 0                False             False                 False
# 1                False             False                 False
# 2                False             False                 False
# 3                False             False                 False
# 4                False             False                 False
#
#    time_control_1220+5  time_control_15  time_control_15+5  \
# 0                False            False              False
# 1                False            False              False
# 2                False            False              False
# 3                False            False              False
# 4                False            False              False
#
#    time_control_1500+10  time_control_1500+5  time_control_1510  \
# 0                 False                False              False
# 1                 False                False              False
# 2                 False                False              False
# 3                 False                False              False
# 4                 False                False              False
#
#    time_control_1560+10  time_control_180  time_control_180+1  \
# 0                 False              True               False
# 1                 False              True               False
# 2                 False              True               False
# 3                 False              True               False
# 4                 False              True               False
#
#    time_control_180+2  time_control_180+3  time_control_1800  \
# 0               False               False              False
# 1               False               False              False
# 2               False               False              False
# 3               False               False              False
# 4               False               False              False
#
#    time_control_182  time_control_185  time_control_20  time_control_20+1  \
# 0             False             False            False              False
# 1             False             False            False              False
# 2             False             False            False              False
# 3             False             False            False              False
# 4             False             False            False              False
#
#    time_control_240  time_control_240+1  time_control_240+2  \
# 0             False               False               False
# 1             False               False               False
# 2             False               False               False
# 3             False               False               False
# 4             False               False               False
#
#    time_control_2400  time_control_2400+5  time_control_2700  \
# 0              False                False              False
# 1              False                False              False
# 2              False                False              False
# 3              False                False              False
# 4              False                False              False
#
#    time_control_2700+15  time_control_2700+45  time_control_30  \
# 0                 False                 False            False
# 1                 False                 False            False
# 2                 False                 False            False
# 3                 False                 False            False
# 4                 False                 False            False
#
#    time_control_300  time_control_300+1  time_control_300+2  \
# 0             False               False               False
# 1             False               False               False
# 2             False               False               False
# 3             False               False               False
# 4             False               False               False
#
#    time_control_300+3  time_control_300+5  time_control_303  \
# 0               False               False             False
# 1               False               False             False
# 2               False               False             False
# 3               False               False             False
# 4               False               False             False
#
#    time_control_3600  time_control_3600+10  time_control_3600+15  \
# 0              False                 False                 False
# 1              False                 False                 False
# 2              False                 False                 False
# 3              False                 False                 False
# 4              False                 False                 False
#
#    time_control_3600+5  time_control_40  time_control_420+2  \
# 0                False            False               False
# 1                False            False               False
# 2                False            False               False
# 3                False            False               False
# 4                False            False               False
#
#    time_control_420+3  time_control_420+5  time_control_421+2  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    time_control_4500+5  time_control_480+5  time_control_5400  \
# 0                False               False              False
# 1                False               False              False
# 2                False               False              False
# 3                False               False              False
# 4                False               False              False
#
#    time_control_5400+30  time_control_546+4  time_control_6  time_control_60  \
# 0                 False               False           False            False
# 1                 False               False           False            False
# 2                 False               False           False            False
# 3                 False               False           False            False
# 4                 False               False           False            False
#
#    time_control_60+1  time_control_60+2  time_control_60+3  time_control_60+6  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    time_control_600  time_control_600+10  time_control_600+2  \
# 0             False                False               False
# 1             False                False               False
# 2             False                False               False
# 3             False                False               False
# 4             False                False               False
#
#    time_control_600+3  time_control_600+5  time_control_602  time_control_61  \
# 0               False               False             False            False
# 1               False               False             False            False
# 2               False               False             False            False
# 3               False               False             False            False
# 4               False               False             False            False
#
#    time_control_62  time_control_7200  time_control_7200+60  time_control_900  \
# 0            False              False                 False             False
# 1            False              False                 False             False
# 2            False              False                 False             False
# 3            False              False                 False             False
# 4            False              False                 False             False
#
#    time_control_900+10  time_control_900+2  time_control_900+3  \
# 0                False               False               False
# 1                False               False               False
# 2                False               False               False
# 3                False               False               False
# 4                False               False               False
#
#    time_control_900+5  time_control_Unknown  ...  \
# 0               False                 False  ...
# 1               False                 False  ...
# 2               False                 False  ...
# 3               False                 False  ...
# 4               False                 False  ...
#
#    event_https://api.chess.com/pub/tournament/the-4th-flaming-tiger-online-blitz-event-1180933  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/the-accused-5283897  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/the-after-party-4443909  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/the-battle-of-helms-deep-1  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/the-best-1-2021  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/the-biggest-world-chess-championship-2025  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/the-new-tournament-welcome  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/the-qualifying-stage-1825362  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/the-queens-gambit-5-1  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/the-warsaw-rising-tournament-2024-1851-2150  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/this-sunday-we-have-a-tournament-with-prizes-439035  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/this-will-go-into-2022-and-beyond  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titeld-tuesday--4140845  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-august-03-2021-2500049  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-august-17-2021-2528831  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-august-31-2021-2546688  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-december-07-2021-2779114  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-december-14-2021-2793478  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-december-21-2021-2825101  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-december-28-2021-2825102  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-february-01-2022-a-2930234  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-february-01-2022-b-2930235  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-january-04-2022-2854823  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-january-11-2022-2868439  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-january-18-2022-2892377  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-january-25-2022-2906225  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-july-06-2021-2443189  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-july-13-2021-2457070  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-july-20-2021-2471236  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-june-01-2021-2359358  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-june-08-2021-2384337  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-june-15-2021-2399019  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-june-22-2021-2413621  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-june-29-2021-2428655  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-may-11-2021-2314015  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-may-18-2021-2319376  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-may-25-2021-2333682  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-may-4-2021-2288851  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-november-02-2021-2688099  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-november-09-2021-2710127  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-november-16-2021-2736618  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-november-23-2021-2750236  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-november-30-2021-2764222  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-october-05-2021-2640054  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-october-12-2021-2654644  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-october-19-2021-2669205  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-october-26-2021-2673117  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-september-02-2025-5905663  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-september-07-2021-2562438  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-september-09-2025-5905665  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/titled-tuesday-blitz-september-16-2025-5925403  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneios-200k-gm-evandro-4409363  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-1-ajedrez-503-1246781  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-abierto-47-aniversario-universidad-nacional-de-entre-ros-1222837  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-blitz-v-san-salvador--3247207  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-chesschocomath-blitz-5909687  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-con-los-maestros-1538828  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-con-premios-3070984  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-de-ajedrez-en-lnea-jden-2024-etapa-regional---regin-central-masculino--4816110  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-de-invierno-9  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-fenamac-1596399  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-matecitos--3562545  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-online-pergamino-3807923  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-por-diversion-214186  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-prueba-5  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-solidario-jorge-fernndez--3979237  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-solidario-jorge-fernndez-4053995  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torneo-torre-blanca-domingo-22-3-18-hs-1163961  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torre-blanca-blitz-del-lunes-23-de-marzo-18-hs-1164834  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/torre-blanca-de-madrugada-1163742  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/tournament-00000000385bc3ca0000000000125ca4  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/tournament-for-honest-players  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/tournoi-1b  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/tsct-2022-amateur-blitz-1659334  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/ttb-open-2020-1  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/turnaj-pratelstvi  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/uefa-nations-league-2022-23-germany-1  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/uji-coba-xclusive-challenge-2320265  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/upasya-039-s-tournament  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/us-chess-regular-open-5176709  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/v-torneo-krakens-1311346  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/vidovdanski-kup-2023-vidovdan-cup-2023  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/women-in-chess-foundation---charity-stream-3920711  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/womens-scc-qualifier-11-1273144  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/womens-scc-qualifier-31-1273143  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/womens-speed-chess-qualifier-1272484  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/world-chess-league-summer-practice-arena-august-31st-4399903  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-play-in-1-4977157  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-play-in-2-4977159  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-play-in-3-4977161  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-play-in-4-4977163  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-qualifier-2-3165382  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-qualifier-4361393  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/wscc-qualifier-7-2356652  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/xclusive-challenge-seri-2-u12-2381310  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    event_https://api.chess.com/pub/tournament/zinzino-internetowe-mistrzostwa-polski-1173898  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    time_category_blitz  time_category_bullet  time_category_daily  \
# 0                 True                 False                False
# 1                 True                 False                False
# 2                 True                 False                False
# 3                 True                 False                False
# 4                 True                 False                False
#
#    time_category_rapid
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
#
# [5 rows x 1894 columns]
